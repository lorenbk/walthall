# %%
View()
# Out:
# <style type="text/css">
# #T_3f9f9  {
#   border: 1px solid black;
# }
# #T_3f9f9 thead {
#   border: 1px solid black;
# }
# #T_3f9f9 th {
#   border: 1px solid lightgray;
# }
# #T_3f9f9  td {
#   border: 1px solid lightgray;
# }
# #T_3f9f9 th.col_heading {
#   background-color: #FFFFFF;
#   line-height: 10px;
#   font-family: Helvetica;
#   text-align: center;
#   vertical-align: middle;
# }
# #T_3f9f9 th.col_heading.level0 {
#   font-size: 10pt;
#   font-weight: 525;
#   padding-bottom: 8px;
#   padding-bottom: 12px;
#   background-color: #B7DBB2;
#   color: #000000;
#   line-height: 25px;
#   display: ;
# }
# #T_3f9f9 th.col_heading.level1 {
#   background-color: #B7DBB2;
#   font-weight: 525;
#   font-size: 10pt;
#   line-height: 0px;
#   vertical-align: middle;
#   padding-bottom: 10px;
#   color: black;
#   display: none;
#   text-align: left;
# }
# #T_3f9f9 th.col_heading.level2 {
#   background-color: #B7DBB2;
#   font-weight: 525;
#   font-size: 10pt;
#   line-height: 0px;
# ...
